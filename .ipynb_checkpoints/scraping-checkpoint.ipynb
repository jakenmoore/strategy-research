# %%
from bs4 import BeautifulSoup
import requests

# %%
source = requests.get("https://www.cmegroup.com/trading/fx/g10/euro-fx_quotes_globex_options.html?optionProductId=8116&optionExpiration=8116-G1").text

# %%
soup = BeautifulSoup(source, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if (gt IE 9) |!(IE)]><!-->
# <html class="cmePineapple cmeTransform no-js" lang="en" xml:lang="en">
#  <!--<![endif]-->
#  <head>
#   <!-- add Google Content Experiment (in Publish Mode) //-->
#   <script>
#    (function(H){H.className=H.className.replace(/\bno-js\b/,'js cme-js')})(document.documentElement)
#   </script>
#   <title>
#    EUR/USD Monthly Options EUR/USD Quotes - CME Group
#   </title>
#   <!-- add common meta tags -->
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width,minimum-scale=1.0,maximum-scale=1.0,initial-scale=1.0,user-scalable=0" id="viewport" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <!-- Google Tag Manager -->
#   <script type="text/javascript">
#    var cmeGTMCode = (document.location.hostname.indexOf("www.cmegroup.com") !== -1) ? "GTM-PLCS" : "GTM-MH2Q";
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# ...

# %%
table1 = soup.find("cmeTableResponsiveScrollableWrapper")

print(table1)
# Out:
# None

# %%
import pyperclip
pyperclip.copy(soup.prettify())

# %%
<div class="cmeTableBlockWrapper cmeContentSection cmeContentGroup" style=""><div class="cmeTableResponsiveScrollableWrapper">
		<table id="optionQuotesProductTable1" class="cmeTable cmeOptionsTable" border="0" cellpadding="2" cellspacing="0" summary="Option Quotes Product Table">
			<thead>
				 <tr>
		            <th scope="col" class="cmeStrikePrice invisibleElement cmeFixedColumn" rowspan="2" style="height: 68px; width: 106px; min-width: 106px;">Strike Price</th>
		            <th class="cmeOptionsTableSection" colspan="7"><span>Calls</span></th>
		            <th class="cmeOptionsTableSection" colspan="7"><span>Puts</span></th>
		        </tr>
		        <tr>
					<th scope="col">Updated</th>
						<th scope="col">Volume</th>
					<th scope="col">High</th>
					<th scope="col">Low</th>
					<th scope="col">Prior Settle</th>
					<th scope="col">Change</th>
					<th scope="col">Last</th>
					<th scope="col">Updated</th>
						<th scope="col">Volume</th>
					<th scope="col">High</th>
					<th scope="col">Low</th>
					<th scope="col">Prior Settle</th>
					<th scope="col">Change</th>
					<th scope="col">Last</th>
				</tr>
			</thead>
			<tbody>
				<tr>
					<th scope="row" class="cmeStrikePrice invisibleElement cmeFixedColumn" style="height: 52px; width: 106px;">11975.0</th>
						<td id="optionQuotesProductTable1_EUUG1_C1197_updated" class="cmeUpdatedField cmeCalls">18:02:12 CT<br>14 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_C1197_volume" class="cmeTableRight cmeCalls">0</td>
						<td id="optionQuotesProductTable1_EUUG1_C1197_high" class="cmeCalls"><span class="noWrap">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1197_low" class="cmeCalls"><span class="noWrap">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1197_priorSettle" class="cmeCalls">0.0214</td>
						<td id="optionQuotesProductTable1_EUUG1_C1197_change" class="cmeCalls statusNull"><span class="statusNull">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1197_last" class="cmeCalls"><span class="noWrap">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1197_updated" class="cmeUpdatedField cmePuts">13:24:12 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_P1197_volume" class="cmeTableRight cmePuts">33</td>
						<td id="optionQuotesProductTable1_EUUG1_P1197_high" class="cmePuts"><span class="noWrap">0.0031</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1197_low" class="cmePuts"><span class="noWrap">0.0025</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1197_priorSettle" class="cmePuts">0.0018</td>
						<td id="optionQuotesProductTable1_EUUG1_P1197_change" class="cmePuts statusOK"><span class="statusOK">+0.0012</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1197_last" class="cmePuts"><span class="noWrap">0.0030</span></td>
				</tr>
				<tr>
					<th scope="row" class="cmeStrikePrice invisibleElement cmeFixedColumn" style="height: 52px; width: 106px;">12000.0</th>
						<td id="optionQuotesProductTable1_EUUG1_C1200_updated" class="cmeUpdatedField cmeCalls">09:14:24 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_C1200_volume" class="cmeTableRight cmeCalls">6</td>
						<td id="optionQuotesProductTable1_EUUG1_C1200_high" class="cmeCalls"><span class="noWrap">0.0146</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1200_low" class="cmeCalls"><span class="noWrap">0.0146</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1200_priorSettle" class="cmeCalls">0.0193</td>
						<td id="optionQuotesProductTable1_EUUG1_C1200_change" class="cmeCalls statusAlert"><span class="statusAlert">-0.0047</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1200_last" class="cmeCalls"><span class="noWrap">0.0146</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1200_updated" class="cmeUpdatedField cmePuts">13:28:35 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_P1200_volume" class="cmeTableRight cmePuts">730</td>
						<td id="optionQuotesProductTable1_EUUG1_P1200_high" class="cmePuts"><span class="noWrap">0.0038</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1200_low" class="cmePuts"><span class="noWrap">0.0024</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1200_priorSettle" class="cmePuts">0.0022</td>
						<td id="optionQuotesProductTable1_EUUG1_P1200_change" class="cmePuts statusOK"><span class="statusOK">+0.0016</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1200_last" class="cmePuts"><span class="noWrap">0.0038</span></td>
				</tr>
				<tr>
					<th scope="row" class="cmeStrikePrice invisibleElement cmeFixedColumn" style="height: 52px; width: 106px;">12025.0</th>
						<td id="optionQuotesProductTable1_EUUG1_C1202_updated" class="cmeUpdatedField cmeCalls">18:01:30 CT<br>14 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_C1202_volume" class="cmeTableRight cmeCalls">0</td>
						<td id="optionQuotesProductTable1_EUUG1_C1202_high" class="cmeCalls"><span class="noWrap">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1202_low" class="cmeCalls"><span class="noWrap">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1202_priorSettle" class="cmeCalls">0.0172</td>
						<td id="optionQuotesProductTable1_EUUG1_C1202_change" class="cmeCalls statusNull"><span class="statusNull">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1202_last" class="cmeCalls"><span class="noWrap">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1202_updated" class="cmeUpdatedField cmePuts">08:21:45 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_P1202_volume" class="cmeTableRight cmePuts">0</td>
						<td id="optionQuotesProductTable1_EUUG1_P1202_high" class="cmePuts"><span class="noWrap">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1202_low" class="cmePuts"><span class="noWrap">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1202_priorSettle" class="cmePuts">0.0027</td>
						<td id="optionQuotesProductTable1_EUUG1_P1202_change" class="cmePuts statusNull"><span class="statusNull">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1202_last" class="cmePuts"><span class="noWrap">-</span></td>
				</tr>
				<tr>
					<th scope="row" class="cmeStrikePrice invisibleElement cmeFixedColumn" style="height: 52px; width: 106px;">12050.0</th>
						<td id="optionQuotesProductTable1_EUUG1_C1205_updated" class="cmeUpdatedField cmeCalls">13:14:58 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_C1205_volume" class="cmeTableRight cmeCalls">4</td>
						<td id="optionQuotesProductTable1_EUUG1_C1205_high" class="cmeCalls"><span class="noWrap">0.0104</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1205_low" class="cmeCalls"><span class="noWrap">0.0102</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1205_priorSettle" class="cmeCalls">0.0153</td>
						<td id="optionQuotesProductTable1_EUUG1_C1205_change" class="cmeCalls statusAlert"><span class="statusAlert">-0.0051</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1205_last" class="cmeCalls"><span class="noWrap">0.0102</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1205_updated" class="cmeUpdatedField cmePuts">12:35:52 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_P1205_volume" class="cmeTableRight cmePuts">555</td>
						<td id="optionQuotesProductTable1_EUUG1_P1205_high" class="cmePuts"><span class="noWrap">0.0055</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1205_low" class="cmePuts"><span class="noWrap">0.0037</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1205_priorSettle" class="cmePuts">0.0033</td>
						<td id="optionQuotesProductTable1_EUUG1_P1205_change" class="cmePuts statusOK"><span class="statusOK">+0.0022</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1205_last" class="cmePuts"><span class="noWrap">0.0055</span></td>
				</tr>
				<tr>
					<th scope="row" class="cmeStrikePrice invisibleElement cmeFixedColumn" style="height: 52px; width: 106px;">12075.0</th>
						<td id="optionQuotesProductTable1_EUUG1_C1207_updated" class="cmeUpdatedField cmeCalls">18:02:49 CT<br>14 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_C1207_volume" class="cmeTableRight cmeCalls">0</td>
						<td id="optionQuotesProductTable1_EUUG1_C1207_high" class="cmeCalls"><span class="noWrap">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1207_low" class="cmeCalls"><span class="noWrap">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1207_priorSettle" class="cmeCalls">0.0135</td>
						<td id="optionQuotesProductTable1_EUUG1_C1207_change" class="cmeCalls statusNull"><span class="statusNull">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1207_last" class="cmeCalls"><span class="noWrap">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1207_updated" class="cmeUpdatedField cmePuts">12:44:14 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_P1207_volume" class="cmeTableRight cmePuts">2</td>
						<td id="optionQuotesProductTable1_EUUG1_P1207_high" class="cmePuts"><span class="noWrap">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1207_low" class="cmePuts"><span class="noWrap">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1207_priorSettle" class="cmePuts">0.0040</td>
						<td id="optionQuotesProductTable1_EUUG1_P1207_change" class="cmePuts statusNull"><span class="statusNull">-</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1207_last" class="cmePuts"><span class="noWrap">-</span></td>
				</tr>
				<tr>
					<th scope="row" class="cmeStrikePrice invisibleElement cmeFixedColumn" style="height: 52px; width: 106px;">12100.0</th>
						<td id="optionQuotesProductTable1_EUUG1_C1210_updated" class="cmeUpdatedField cmeCalls">13:41:18 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_C1210_volume" class="cmeTableRight cmeCalls">22</td>
						<td id="optionQuotesProductTable1_EUUG1_C1210_high" class="cmeCalls"><span class="noWrap">0.0090</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1210_low" class="cmeCalls"><span class="noWrap">0.0072</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1210_priorSettle" class="cmeCalls">0.0118</td>
						<td id="optionQuotesProductTable1_EUUG1_C1210_change" class="cmeCalls statusAlert"><span class="statusAlert">-0.0046</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1210_last" class="cmeCalls"><span class="noWrap">0.0072</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1210_updated" class="cmeUpdatedField cmePuts">13:29:43 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_P1210_volume" class="cmeTableRight cmePuts">27</td>
						<td id="optionQuotesProductTable1_EUUG1_P1210_high" class="cmePuts"><span class="noWrap">0.0075</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1210_low" class="cmePuts"><span class="noWrap">0.0061</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1210_priorSettle" class="cmePuts">0.0048</td>
						<td id="optionQuotesProductTable1_EUUG1_P1210_change" class="cmePuts statusOK"><span class="statusOK">+0.0027</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1210_last" class="cmePuts"><span class="noWrap">0.0075</span></td>
				</tr>
				<tr>
					<th scope="row" class="cmeStrikePrice invisibleElement cmeFixedColumn" style="height: 52px; width: 106px;">12125.0</th>
						<td id="optionQuotesProductTable1_EUUG1_C1212_updated" class="cmeUpdatedField cmeCalls">12:22:07 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_C1212_volume" class="cmeTableRight cmeCalls">24</td>
						<td id="optionQuotesProductTable1_EUUG1_C1212_high" class="cmeCalls"><span class="noWrap">0.0077</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1212_low" class="cmeCalls"><span class="noWrap">0.0061</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1212_priorSettle" class="cmeCalls">0.0102</td>
						<td id="optionQuotesProductTable1_EUUG1_C1212_change" class="cmeCalls statusAlert"><span class="statusAlert">-0.0041</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1212_last" class="cmeCalls"><span class="noWrap">0.0061</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1212_updated" class="cmeUpdatedField cmePuts">10:56:39 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_P1212_volume" class="cmeTableRight cmePuts">4</td>
						<td id="optionQuotesProductTable1_EUUG1_P1212_high" class="cmePuts"><span class="noWrap">0.0085</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1212_low" class="cmePuts"><span class="noWrap">0.0061</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1212_priorSettle" class="cmePuts">0.0057</td>
						<td id="optionQuotesProductTable1_EUUG1_P1212_change" class="cmePuts statusOK"><span class="statusOK">+0.0028</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1212_last" class="cmePuts"><span class="noWrap">0.0085</span></td>
				</tr>
				<tr>
					<th scope="row" class="cmeStrikePrice invisibleElement cmeFixedColumn" style="height: 52px; width: 106px;">12150.0</th>
						<td id="optionQuotesProductTable1_EUUG1_C1215_updated" class="cmeUpdatedField cmeCalls">13:37:07 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_C1215_volume" class="cmeTableRight cmeCalls">94</td>
						<td id="optionQuotesProductTable1_EUUG1_C1215_high" class="cmeCalls"><span class="noWrap">0.0075</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1215_low" class="cmeCalls"><span class="noWrap">0.0051</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1215_priorSettle" class="cmeCalls">0.0088</td>
						<td id="optionQuotesProductTable1_EUUG1_C1215_change" class="cmeCalls statusAlert"><span class="statusAlert">-0.0037</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1215_last" class="cmeCalls"><span class="noWrap">0.0051</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1215_updated" class="cmeUpdatedField cmePuts">13:23:02 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_P1215_volume" class="cmeTableRight cmePuts">38</td>
						<td id="optionQuotesProductTable1_EUUG1_P1215_high" class="cmePuts"><span class="noWrap">0.0102</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1215_low" class="cmePuts"><span class="noWrap">0.0070</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1215_priorSettle" class="cmePuts">0.0068</td>
						<td id="optionQuotesProductTable1_EUUG1_P1215_change" class="cmePuts statusOK"><span class="statusOK">+0.0031</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1215_last" class="cmePuts"><span class="noWrap">0.0099</span></td>
				</tr>
				<tr>
					<th scope="row" class="cmeStrikePrice invisibleElement cmeFixedColumn" style="height: 52px; width: 106px;">12175.0</th>
						<td id="optionQuotesProductTable1_EUUG1_C1217_updated" class="cmeUpdatedField cmeCalls">13:45:08 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_C1217_volume" class="cmeTableRight cmeCalls">8</td>
						<td id="optionQuotesProductTable1_EUUG1_C1217_high" class="cmeCalls"><span class="noWrap">0.0071</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1217_low" class="cmeCalls"><span class="noWrap">0.0044</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1217_priorSettle" class="cmeCalls">0.0075</td>
						<td id="optionQuotesProductTable1_EUUG1_C1217_change" class="cmeCalls statusAlert"><span class="statusAlert">-0.0031</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1217_last" class="cmeCalls"><span class="noWrap">0.0044</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1217_updated" class="cmeUpdatedField cmePuts">08:56:24 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_P1217_volume" class="cmeTableRight cmePuts">1</td>
						<td id="optionQuotesProductTable1_EUUG1_P1217_high" class="cmePuts"><span class="noWrap">0.0110</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1217_low" class="cmePuts"><span class="noWrap">0.0110</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1217_priorSettle" class="cmePuts">0.0080</td>
						<td id="optionQuotesProductTable1_EUUG1_P1217_change" class="cmePuts statusOK"><span class="statusOK">+0.0030</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1217_last" class="cmePuts"><span class="noWrap">0.0110</span></td>
				</tr>
				<tr>
					<th scope="row" class="cmeStrikePrice invisibleElement cmeFixedColumn" style="height: 52px; width: 106px;">12200.0</th>
						<td id="optionQuotesProductTable1_EUUG1_C1220_updated" class="cmeUpdatedField cmeCalls">12:39:19 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_C1220_volume" class="cmeTableRight cmeCalls">38</td>
						<td id="optionQuotesProductTable1_EUUG1_C1220_high" class="cmeCalls"><span class="noWrap">0.0053</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1220_low" class="cmeCalls"><span class="noWrap">0.0033</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1220_priorSettle" class="cmeCalls">0.0063</td>
						<td id="optionQuotesProductTable1_EUUG1_C1220_change" class="cmeCalls statusAlert"><span class="statusAlert">-0.0029</span></td>
						<td id="optionQuotesProductTable1_EUUG1_C1220_last" class="cmeCalls"><span class="noWrap">0.0034</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1220_updated" class="cmeUpdatedField cmePuts">11:30:15 CT<br>15 Jan 2021</td>
						<td id="optionQuotesProductTable1_EUUG1_P1220_volume" class="cmeTableRight cmePuts">24</td>
						<td id="optionQuotesProductTable1_EUUG1_P1220_high" class="cmePuts"><span class="noWrap">0.0117</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1220_low" class="cmePuts"><span class="noWrap">0.0098</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1220_priorSettle" class="cmePuts">0.0093</td>
						<td id="optionQuotesProductTable1_EUUG1_P1220_change" class="cmePuts statusOK"><span class="statusOK">+0.0024</span></td>
						<td id="optionQuotesProductTable1_EUUG1_P1220_last" class="cmePuts"><span class="noWrap">0.0117</span></td>
				</tr>
			</tbody>
		</table>
	</div>

	<div class="cmeTableResponsivePinnedWrapper" style="top: 0px; width: 117px;">
		<table id="optionQuotesProductTable1Mobile" class="cmePinnedTable cmeOptionsTable" border="0" cellpadding="2" cellspacing="0" summary="Option Quotes Product Table">
			<thead>
				<tr>
					<th scope="col" class="cmeStrikePrice cmePinnedColumn cmeFixedColumn" style="height: 68px; min-width: 106px;">Strike Price</th>
				</tr>
			</thead>
			<tbody>
					<tr>
						<th scope="row" class="cmePinnedColumn cmeFixedColumn" style="height: 52px; width: 106px;">11975.0</th>
					</tr>
					<tr>
						<th scope="row" class="cmePinnedColumn cmeFixedColumn" style="height: 52px; width: 106px;">12000.0</th>
					</tr>
					<tr>
						<th scope="row" class="cmePinnedColumn cmeFixedColumn" style="height: 52px; width: 106px;">12025.0</th>
					</tr>
					<tr>
						<th scope="row" class="cmePinnedColumn cmeFixedColumn" style="height: 52px; width: 106px;">12050.0</th>
					</tr>
					<tr>
						<th scope="row" class="cmePinnedColumn cmeFixedColumn" style="height: 52px; width: 106px;">12075.0</th>
					</tr>
					<tr>
						<th scope="row" class="cmePinnedColumn cmeFixedColumn" style="height: 52px; width: 106px;">12100.0</th>
					</tr>
					<tr>
						<th scope="row" class="cmePinnedColumn cmeFixedColumn" style="height: 52px; width: 106px;">12125.0</th>
					</tr>
					<tr>
						<th scope="row" class="cmePinnedColumn cmeFixedColumn" style="height: 52px; width: 106px;">12150.0</th>
					</tr>
					<tr>
						<th scope="row" class="cmePinnedColumn cmeFixedColumn" style="height: 52px; width: 106px;">12175.0</th>
					</tr>
					<tr>
						<th scope="row" class="cmePinnedColumn cmeFixedColumn" style="height: 52px; width: 106px;">12200.0</th>
					</tr>
			</tbody>
		</table>
	</div>

	<div class="cmeComponent">
		<ul class="cmeLegend">
			<li class="cmeLegendItem cmeSupportingLinkIcon cmeAboutListIcon"><a rel="popup" href="../../about-quotes.html"><span>About This Report</span></a></li>
		</ul>
	</div></div>
