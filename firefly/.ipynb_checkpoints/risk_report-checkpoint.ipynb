# %% [markdown]
# # Kaiseki Systems

# %% [markdown]
# ## Firefly Risk Report

# %%
#%% import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import plotting
from tabulate import tabulate
import utilities.Database_Utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-84e1e37dac33> in <module>
#       4 import matplotlib.pyplot as plt
#       5
# ----> 6 import plotting
#       7 from tabulate import tabulate
#       8 import utilities.Database_Utils
#
# ~/Code/kaiseki/research/firefly/plotting.py in <module>
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
# ----> 5 import risk_calc as rc
#       6
#       7 #%% plot VaR for 1000 lookbacks
#
# ModuleNotFoundError: No module named 'risk_calc'

# %%
# import the data
startdate = '2010-01-01'
enddate = '2018-12-31'
resample_period = "b"
fx_data = rc.read_pickle("hourly_fx_close", startdate, enddate, resample_period)

# %%
# set up: returns, positions, portfolio amounts
fx_rets = fx_data.pct_change()
NAV = 1000000
pct_positions = np.array([0.6, -0.3, -0.6, 0.45, 0.25, 0.2, -0.78, -0.3, 0.2])

# %%
test = rc.risk_results(fx_rets, pct_positions)

# %%
rc.print_risk_results(test)
# Out:
# Metric                Risk % Portfolio
# ------------------  ------------------
# HVaR_95_2y                 -0.00957663
# CVaR_95_2y                 -0.0123932
# HVaR_99_2y                 -0.0127445
# CVaR_99_2y                 -0.0165277
# portfolio_notional          3.68
# Brexit_Stress              -0.026468

# %%
plotting.plot_hist(fx_rets, pct_positions)

# %%
plotting.plot_convergence(fx_rets, pct_positions)

# %%
import utilities.Database_Utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-547061abda88> in <module>
# ----> 1 import utilities.Database_Utils
#
# ModuleNotFoundError: No module named 'utilities'
